# %%
from transformers import ViTFeatureExtractor, TFViTMAEForPreTraining
from tensorflow import keras
from tensorflow.keras import layers
import tensorflow as tf
import numpy as np
from PIL import Image

# %%
tf.config.list_physical_devices('GPU')

tf.keras.backend.clear_session()
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
classification_train_dataset = tf.keras.utils.image_dataset_from_directory(
    directory="e:/TFM/PlantsClassification/train",
    image_size=(224,224),
    batch_size=64,
    label_mode="int",
    color_mode="rgb",
    shuffle=True
).map(lambda x, y: (tf.cast(x, tf.float32) / 255.0, y)).prefetch(tf.data.AUTOTUNE)

classification_val_dataset = tf.keras.utils.image_dataset_from_directory(
    directory="e:/TFM/PlantsClassification/val",
    image_size=(224,224),
    batch_size=64,
    label_mode="int",
    color_mode="rgb",
    shuffle=False
).map(lambda x, y: (tf.cast(x, tf.float32) / 255.0, y)).prefetch(tf.data.AUTOTUNE)

classification_test_dataset = tf.keras.utils.image_dataset_from_directory(
    directory="e:/TFM/PlantsClassification/test",
    image_size=(224,224),
    batch_size=64,
    label_mode="int",
    color_mode="rgb",
    shuffle=False
).map(lambda x, y: (tf.cast(x, tf.float32) / 255.0, y)).prefetch(tf.data.AUTOTUNE)

feature_extractor = ViTFeatureExtractor.from_pretrained("facebook/vit-mae-base")

def preprocess_batch(images, labels):
    def _preprocess(images_np):
        # De [0,1] a [0,255] y a uint8
        images_np = (images_np * 255.0).astype(np.uint8)
        # Preprocesa todo el batch
        processed = feature_extractor(images=list(images_np), return_tensors="np")
        # Retorna (batch_size, 3, 224, 224)
        return processed["pixel_values"].astype(np.float32)

    images = tf.numpy_function(_preprocess, [images], tf.float32)
    images.set_shape([None, 3, 224, 224])  # None = batch size variable
    return images, labels

final_train_dataset = classification_train_dataset.map(
    preprocess_batch,
    num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)


final_test_dataset = classification_test_dataset.map(
    preprocess_batch,
    num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)

final_val_dataset = classification_val_dataset.map(
    preprocess_batch,
    num_parallel_calls=tf.data.AUTOTUNE
).prefetch(tf.data.AUTOTUNE)
# Out:
# Found 21000 files belonging to 30 classes.
# Found 3000 files belonging to 30 classes.
# Found 6000 files belonging to 30 classes.
# c:\Users\Usuario\miniconda3\envs\rotnet\lib\site-packages\transformers\models\vit\feature_extraction_vit.py:30: FutureWarning: The class ViTFeatureExtractor is deprecated and will be removed in version 5 of Transformers. Please use ViTImageProcessor instead.
#   warnings.warn(

# %%
# 1️⃣ Carga el modelo ViT-MAE preentrenado (solo queremos el encoder)
mae_model = TFViTMAEForPreTraining.from_pretrained("facebook/vit-mae-base")
vit_encoder = mae_model.vit

# 2️⃣ Congela el encoder (opcional: lo puedes descongelar más adelante para fine-tuning)
vit_encoder.trainable = False

# 3️⃣ Define el modelo Keras
inputs = keras.Input(shape=(3, 224, 224))
x = vit_encoder(pixel_values=inputs, training=False)[0]  # [0]: el output del encoder

cls_token_output = x[:, 0, :]

# --- INICIO DE LA NUEVA CABEZA ROBUSTA Y REGULARIZADA ---

# Capa de normalización inicial para estabilizar la entrada al head
x = layers.LayerNormalization()(cls_token_output)

# Primera capa Dense con regularización L2 y Batch Normalization
x = layers.Dense(1024,activation='relu',kernel_regularizer=keras.regularizers.l2(0.001))(x)
x = layers.BatchNormalization()(x) # Normalización de lotes para estabilidad
x = layers.Dropout(0.3)(x) # Dropout para regularización

# Segunda capa Dense con regularización L2 y Batch Normalization
x = layers.Dense(512,activation='relu',kernel_regularizer=keras.regularizers.l2(0.001))(x)
x = layers.BatchNormalization()(x) # Normalización de lotes para estabilidad
x = layers.Dropout(0.3)(x) # Dropout para regularización
outputs = layers.Dense(30, activation='softmax')(x)  # 30 clases

model = keras.Model(inputs, outputs)

# 4️⃣ Compila el modelo

model.summary()
# Out:
# All PyTorch model weights were used when initializing TFViTMAEForPreTraining.
#
# All the weights of TFViTMAEForPreTraining were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFViTMAEForPreTraining for predictions without further training.
# Model: "model_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 3, 224, 224)]     0
#
#  vit (TFViTMAEMainLayer)     TFViTMAEModelOutput(last  85798656
#                              _hidden_state=(None, 50,
#                               768),
#                               mask=(None, 196),
#                               ids_restore=(None, 196)
#                              , hidden_states=None, at
#                              tentions=None)
#
#  tf.__operators__.getitem_1   (None, 768)              0
#  (SlicingOpLambda)
#
#  layer_normalization_1 (Laye  (None, 768)              1536
#  rNormalization)
#
#  dense_3 (Dense)             (None, 1024)              787456
#
#  batch_normalization_2 (Batc  (None, 1024)             4096
#  hNormalization)
#
#  dropout_122 (Dropout)       (None, 1024)              0
#
#  dense_4 (Dense)             (None, 512)               524800
#
#  batch_normalization_3 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dropout_123 (Dropout)       (None, 512)               0
#
#  dense_5 (Dense)             (None, 30)                15390
#
# =================================================================
# Total params: 87,133,982
# Trainable params: 1,332,254
# Non-trainable params: 85,801,728
# _________________________________________________________________

# %%
for images, labels in final_train_dataset.take(1):
    print("Shape de las imágenes en el batch:", images.shape)
    print("Shape de las etiquetas:", labels.shape)
# Out:
# Shape de las imágenes en el batch: (64, 3, 224, 224)
# Shape de las etiquetas: (64,)

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)


callbacks = [
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=10 , restore_best_weights=True, verbose=1),
    keras.callbacks.ModelCheckpoint(filepath='best_modelV2.h5', save_best_only=True, monitor='val_loss'),
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', verbose=1,factor=0.5),
]

history = model.fit(
    final_train_dataset,
    validation_data=final_test_dataset,
    epochs=100,
    callbacks=callbacks,
    verbose=1

)
#save
model.save("vit_mae_finetunedV2.h5")
# Out:
# Epoch 1/100
# 329/329 [==============================] - 116s 314ms/step - loss: 3.9507 - accuracy: 0.3150 - val_loss: 2.8715 - val_accuracy: 0.5660 - lr: 1.0000e-04
# Epoch 2/100
# 329/329 [==============================] - 95s 280ms/step - loss: 2.8770 - accuracy: 0.5162 - val_loss: 2.2779 - val_accuracy: 0.6693 - lr: 1.0000e-04
# Epoch 3/100
# 329/329 [==============================] - 94s 279ms/step - loss: 2.5587 - accuracy: 0.5831 - val_loss: 2.1154 - val_accuracy: 0.7100 - lr: 1.0000e-04
# Epoch 4/100
# 329/329 [==============================] - 97s 288ms/step - loss: 2.3670 - accuracy: 0.6265 - val_loss: 1.9879 - val_accuracy: 0.7298 - lr: 1.0000e-04
# Epoch 5/100
# 329/329 [==============================] - 96s 284ms/step - loss: 2.2347 - accuracy: 0.6525 - val_loss: 1.8945 - val_accuracy: 0.7432 - lr: 1.0000e-04
# Epoch 6/100
# 329/329 [==============================] - 97s 287ms/step - loss: 2.1142 - accuracy: 0.6776 - val_loss: 1.8402 - val_accuracy: 0.7583 - lr: 1.0000e-04
# Epoch 7/100
# 329/329 [==============================] - 96s 284ms/step - loss: 2.0331 - accuracy: 0.6904 - val_loss: 1.7764 - val_accuracy: 0.7638 - lr: 1.0000e-04
# Epoch 8/100
# 329/329 [==============================] - 96s 283ms/step - loss: 1.9516 - accuracy: 0.7054 - val_loss: 1.7194 - val_accuracy: 0.7683 - lr: 1.0000e-04
# Epoch 9/100
# 329/329 [==============================] - 96s 283ms/step - loss: 1.8849 - accuracy: 0.7175 - val_loss: 1.6705 - val_accuracy: 0.7777 - lr: 1.0000e-04
# Epoch 10/100
# 329/329 [==============================] - 96s 283ms/step - loss: 1.8036 - accuracy: 0.7335 - val_loss: 1.6352 - val_accuracy: 0.7813 - lr: 1.0000e-04
# Epoch 11/100
# 329/329 [==============================] - 96s 283ms/step - loss: 1.7589 - accuracy: 0.7360 - val_loss: 1.6077 - val_accuracy: 0.7798 - lr: 1.0000e-04
# Epoch 12/100
# 329/329 [==============================] - 96s 284ms/step - loss: 1.7002 - accuracy: 0.7473 - val_loss: 1.5487 - val_accuracy: 0.7883 - lr: 1.0000e-04
# Epoch 13/100
# 329/329 [==============================] - 96s 284ms/step - loss: 1.6425 - accuracy: 0.7548 - val_loss: 1.5230 - val_accuracy: 0.7910 - lr: 1.0000e-04
# Epoch 14/100
# 329/329 [==============================] - 95s 281ms/step - loss: 1.6221 - accuracy: 0.7564 - val_loss: 1.5060 - val_accuracy: 0.7905 - lr: 1.0000e-04
# Epoch 15/100
# 329/329 [==============================] - 95s 282ms/step - loss: 1.5581 - accuracy: 0.7630 - val_loss: 1.4418 - val_accuracy: 0.8018 - lr: 1.0000e-04
# Epoch 16/100
# 329/329 [==============================] - 95s 281ms/step - loss: 1.5124 - accuracy: 0.7749 - val_loss: 1.4252 - val_accuracy: 0.8040 - lr: 1.0000e-04
# Epoch 17/100
# 329/329 [==============================] - 96s 285ms/step - loss: 1.4703 - accuracy: 0.7804 - val_loss: 1.4038 - val_accuracy: 0.7970 - lr: 1.0000e-04
# Epoch 18/100
# 329/329 [==============================] - 95s 282ms/step - loss: 1.4361 - accuracy: 0.7824 - val_loss: 1.3844 - val_accuracy: 0.7972 - lr: 1.0000e-04
# Epoch 19/100
# 329/329 [==============================] - 96s 284ms/step - loss: 1.4055 - accuracy: 0.7855 - val_loss: 1.3469 - val_accuracy: 0.8103 - lr: 1.0000e-04
# Epoch 20/100
# 329/329 [==============================] - 95s 282ms/step - loss: 1.3587 - accuracy: 0.7959 - val_loss: 1.3406 - val_accuracy: 0.8063 - lr: 1.0000e-04
# Epoch 21/100
# 329/329 [==============================] - 96s 283ms/step - loss: 1.3372 - accuracy: 0.7967 - val_loss: 1.3080 - val_accuracy: 0.8087 - lr: 1.0000e-04
# Epoch 22/100
# 329/329 [==============================] - 95s 282ms/step - loss: 1.3052 - accuracy: 0.7983 - val_loss: 1.3050 - val_accuracy: 0.8073 - lr: 1.0000e-04
# Epoch 23/100
# 329/329 [==============================] - 96s 285ms/step - loss: 1.2802 - accuracy: 0.8027 - val_loss: 1.2735 - val_accuracy: 0.8132 - lr: 1.0000e-04
# Epoch 24/100
# 329/329 [==============================] - 95s 282ms/step - loss: 1.2519 - accuracy: 0.8069 - val_loss: 1.2325 - val_accuracy: 0.8153 - lr: 1.0000e-04
# Epoch 25/100
# 329/329 [==============================] - 96s 283ms/step - loss: 1.2209 - accuracy: 0.8094 - val_loss: 1.2236 - val_accuracy: 0.8162 - lr: 1.0000e-04
# Epoch 26/100
# 329/329 [==============================] - 96s 284ms/step - loss: 1.1924 - accuracy: 0.8144 - val_loss: 1.1940 - val_accuracy: 0.8170 - lr: 1.0000e-04
# Epoch 27/100
# 329/329 [==============================] - 95s 282ms/step - loss: 1.1723 - accuracy: 0.8167 - val_loss: 1.1826 - val_accuracy: 0.8212 - lr: 1.0000e-04
# Epoch 28/100
# 329/329 [==============================] - 95s 282ms/step - loss: 1.1501 - accuracy: 0.8217 - val_loss: 1.1776 - val_accuracy: 0.8282 - lr: 1.0000e-04
# Epoch 29/100
# 329/329 [==============================] - 95s 282ms/step - loss: 1.1183 - accuracy: 0.8255 - val_loss: 1.1578 - val_accuracy: 0.8198 - lr: 1.0000e-04
# Epoch 30/100
# 329/329 [==============================] - 95s 281ms/step - loss: 1.1030 - accuracy: 0.8264 - val_loss: 1.1049 - val_accuracy: 0.8315 - lr: 1.0000e-04
# Epoch 31/100
# 329/329 [==============================] - 94s 279ms/step - loss: 1.0785 - accuracy: 0.8274 - val_loss: 1.1223 - val_accuracy: 0.8258 - lr: 1.0000e-04
# Epoch 32/100
# 329/329 [==============================] - 94s 278ms/step - loss: 1.0582 - accuracy: 0.8317 - val_loss: 1.1072 - val_accuracy: 0.8255 - lr: 1.0000e-04
# Epoch 33/100
# 329/329 [==============================] - 94s 278ms/step - loss: 1.0388 - accuracy: 0.8347 - val_loss: 1.1153 - val_accuracy: 0.8210 - lr: 1.0000e-04
# Epoch 34/100
# 329/329 [==============================] - 95s 282ms/step - loss: 1.0195 - accuracy: 0.8364 - val_loss: 1.0883 - val_accuracy: 0.8232 - lr: 1.0000e-04
# Epoch 35/100
# 329/329 [==============================] - 94s 279ms/step - loss: 1.0025 - accuracy: 0.8363 - val_loss: 1.0622 - val_accuracy: 0.8273 - lr: 1.0000e-04
# Epoch 36/100
# 329/329 [==============================] - 96s 284ms/step - loss: 0.9713 - accuracy: 0.8437 - val_loss: 1.0552 - val_accuracy: 0.8312 - lr: 1.0000e-04
# Epoch 37/100
# 329/329 [==============================] - 96s 284ms/step - loss: 0.9696 - accuracy: 0.8410 - val_loss: 1.0441 - val_accuracy: 0.8310 - lr: 1.0000e-04
# Epoch 38/100
# 329/329 [==============================] - 96s 284ms/step - loss: 0.9501 - accuracy: 0.8454 - val_loss: 1.0284 - val_accuracy: 0.8307 - lr: 1.0000e-04
# Epoch 39/100
# 329/329 [==============================] - 95s 282ms/step - loss: 0.9387 - accuracy: 0.8458 - val_loss: 1.0079 - val_accuracy: 0.8362 - lr: 1.0000e-04
# Epoch 40/100
# 329/329 [==============================] - 95s 281ms/step - loss: 0.9289 - accuracy: 0.8460 - val_loss: 1.0338 - val_accuracy: 0.8283 - lr: 1.0000e-04
# Epoch 41/100
# 329/329 [==============================] - 96s 284ms/step - loss: 0.9066 - accuracy: 0.8498 - val_loss: 0.9792 - val_accuracy: 0.8367 - lr: 1.0000e-04
# Epoch 42/100
# 329/329 [==============================] - 95s 281ms/step - loss: 0.8929 - accuracy: 0.8508 - val_loss: 1.0114 - val_accuracy: 0.8295 - lr: 1.0000e-04
# Epoch 43/100
# 329/329 [==============================] - 95s 281ms/step - loss: 0.8798 - accuracy: 0.8520 - val_loss: 0.9734 - val_accuracy: 0.8370 - lr: 1.0000e-04
# Epoch 44/100
# 329/329 [==============================] - 95s 282ms/step - loss: 0.8621 - accuracy: 0.8544 - val_loss: 0.9690 - val_accuracy: 0.8335 - lr: 1.0000e-04
# Epoch 45/100
# 329/329 [==============================] - 95s 282ms/step - loss: 0.8543 - accuracy: 0.8549 - val_loss: 0.9605 - val_accuracy: 0.8397 - lr: 1.0000e-04
# Epoch 46/100
# 329/329 [==============================] - 96s 284ms/step - loss: 0.8439 - accuracy: 0.8548 - val_loss: 0.9498 - val_accuracy: 0.8403 - lr: 1.0000e-04
# Epoch 47/100
# 329/329 [==============================] - 95s 282ms/step - loss: 0.8300 - accuracy: 0.8583 - val_loss: 0.9622 - val_accuracy: 0.8303 - lr: 1.0000e-04
# Epoch 48/100
# 329/329 [==============================] - 94s 279ms/step - loss: 0.8253 - accuracy: 0.8571 - val_loss: 0.9698 - val_accuracy: 0.8288 - lr: 1.0000e-04
# Epoch 49/100
# 329/329 [==============================] - 96s 284ms/step - loss: 0.8026 - accuracy: 0.8646 - val_loss: 0.9355 - val_accuracy: 0.8340 - lr: 1.0000e-04
# Epoch 50/100
# 329/329 [==============================] - 95s 282ms/step - loss: 0.8015 - accuracy: 0.8602 - val_loss: 0.9180 - val_accuracy: 0.8418 - lr: 1.0000e-04
# Epoch 51/100
# 329/329 [==============================] - 95s 281ms/step - loss: 0.7822 - accuracy: 0.8639 - val_loss: 0.8912 - val_accuracy: 0.8470 - lr: 1.0000e-04
# Epoch 52/100
# 329/329 [==============================] - 94s 279ms/step - loss: 0.7729 - accuracy: 0.8673 - val_loss: 0.9080 - val_accuracy: 0.8418 - lr: 1.0000e-04
# Epoch 53/100
# 329/329 [==============================] - 95s 280ms/step - loss: 0.7776 - accuracy: 0.8610 - val_loss: 0.9140 - val_accuracy: 0.8328 - lr: 1.0000e-04
# Epoch 54/100
# 329/329 [==============================] - 95s 281ms/step - loss: 0.7700 - accuracy: 0.8633 - val_loss: 0.8838 - val_accuracy: 0.8475 - lr: 1.0000e-04
# Epoch 55/100
# 329/329 [==============================] - 95s 280ms/step - loss: 0.7512 - accuracy: 0.8685 - val_loss: 0.8809 - val_accuracy: 0.8480 - lr: 1.0000e-04
# Epoch 56/100
# 329/329 [==============================] - 95s 282ms/step - loss: 0.7510 - accuracy: 0.8665 - val_loss: 0.8690 - val_accuracy: 0.8495 - lr: 1.0000e-04
# Epoch 57/100
# 329/329 [==============================] - 94s 279ms/step - loss: 0.7290 - accuracy: 0.8704 - val_loss: 0.8816 - val_accuracy: 0.8437 - lr: 1.0000e-04
# Epoch 58/100
# 329/329 [==============================] - 94s 278ms/step - loss: 0.7209 - accuracy: 0.8743 - val_loss: 0.8858 - val_accuracy: 0.8437 - lr: 1.0000e-04
# Epoch 59/100
# 329/329 [==============================] - 94s 277ms/step - loss: 0.7226 - accuracy: 0.8689 - val_loss: 0.8927 - val_accuracy: 0.8415 - lr: 1.0000e-04
# Epoch 60/100
# 329/329 [==============================] - 94s 279ms/step - loss: 0.7063 - accuracy: 0.8713 - val_loss: 0.8828 - val_accuracy: 0.8412 - lr: 1.0000e-04
# Epoch 61/100
# 329/329 [==============================] - 95s 280ms/step - loss: 0.6939 - accuracy: 0.8768 - val_loss: 0.8531 - val_accuracy: 0.8475 - lr: 1.0000e-04
# Epoch 62/100
# 329/329 [==============================] - 94s 279ms/step - loss: 0.6987 - accuracy: 0.8731 - val_loss: 0.8573 - val_accuracy: 0.8445 - lr: 1.0000e-04
# Epoch 63/100
# 329/329 [==============================] - 94s 278ms/step - loss: 0.6873 - accuracy: 0.8750 - val_loss: 0.8676 - val_accuracy: 0.8382 - lr: 1.0000e-04
# Epoch 64/100
# 329/329 [==============================] - 93s 277ms/step - loss: 0.6798 - accuracy: 0.8772 - val_loss: 0.8552 - val_accuracy: 0.8468 - lr: 1.0000e-04
# Epoch 65/100
# 329/329 [==============================] - 94s 278ms/step - loss: 0.6748 - accuracy: 0.8779 - val_loss: 0.8605 - val_accuracy: 0.8397 - lr: 1.0000e-04
# Epoch 66/100
# 329/329 [==============================] - 95s 280ms/step - loss: 0.6654 - accuracy: 0.8760 - val_loss: 0.8292 - val_accuracy: 0.8433 - lr: 1.0000e-04
# Epoch 67/100
# 329/329 [==============================] - 94s 277ms/step - loss: 0.6656 - accuracy: 0.8746 - val_loss: 0.8549 - val_accuracy: 0.8388 - lr: 1.0000e-04
# Epoch 68/100
# 329/329 [==============================] - 94s 278ms/step - loss: 0.6525 - accuracy: 0.8765 - val_loss: 0.8565 - val_accuracy: 0.8370 - lr: 1.0000e-04
# Epoch 69/100
# 329/329 [==============================] - 94s 278ms/step - loss: 0.6487 - accuracy: 0.8804 - val_loss: 0.8318 - val_accuracy: 0.8412 - lr: 1.0000e-04
# Epoch 70/100
# 329/329 [==============================] - 95s 280ms/step - loss: 0.6520 - accuracy: 0.8775 - val_loss: 0.8381 - val_accuracy: 0.8420 - lr: 1.0000e-04
# Epoch 71/100
# 329/329 [==============================] - 96s 283ms/step - loss: 0.6357 - accuracy: 0.8803 - val_loss: 0.8077 - val_accuracy: 0.8457 - lr: 1.0000e-04
# Epoch 72/100
# 329/329 [==============================] - 94s 277ms/step - loss: 0.6382 - accuracy: 0.8797 - val_loss: 0.8137 - val_accuracy: 0.8445 - lr: 1.0000e-04
# Epoch 73/100
# 329/329 [==============================] - 95s 280ms/step - loss: 0.6328 - accuracy: 0.8792 - val_loss: 0.8440 - val_accuracy: 0.8385 - lr: 1.0000e-04
# Epoch 74/100
# 329/329 [==============================] - 94s 279ms/step - loss: 0.6311 - accuracy: 0.8786 - val_loss: 0.8100 - val_accuracy: 0.8497 - lr: 1.0000e-04
# Epoch 75/100
# 329/329 [==============================] - 96s 283ms/step - loss: 0.6137 - accuracy: 0.8832 - val_loss: 0.8076 - val_accuracy: 0.8440 - lr: 1.0000e-04
# Epoch 76/100
# 329/329 [==============================] - 95s 282ms/step - loss: 0.6180 - accuracy: 0.8806 - val_loss: 0.7918 - val_accuracy: 0.8498 - lr: 1.0000e-04
# Epoch 77/100
# 329/329 [==============================] - 93s 276ms/step - loss: 0.6071 - accuracy: 0.8839 - val_loss: 0.8266 - val_accuracy: 0.8427 - lr: 1.0000e-04
# Epoch 78/100
# 329/329 [==============================] - 94s 277ms/step - loss: 0.6087 - accuracy: 0.8823 - val_loss: 0.7929 - val_accuracy: 0.8478 - lr: 1.0000e-04
# Epoch 79/100
# 329/329 [==============================] - 94s 278ms/step - loss: 0.5916 - accuracy: 0.8865 - val_loss: 0.8128 - val_accuracy: 0.8397 - lr: 1.0000e-04
# Epoch 80/100
# 329/329 [==============================] - 94s 277ms/step - loss: 0.5912 - accuracy: 0.8849 - val_loss: 0.8000 - val_accuracy: 0.8438 - lr: 1.0000e-04
# Epoch 81/100
# 329/329 [==============================] - 94s 278ms/step - loss: 0.5875 - accuracy: 0.8867 - val_loss: 0.7968 - val_accuracy: 0.8445 - lr: 1.0000e-04
# Epoch 82/100
# 329/329 [==============================] - 94s 279ms/step - loss: 0.5914 - accuracy: 0.8850 - val_loss: 0.8218 - val_accuracy: 0.8442 - lr: 1.0000e-04
# Epoch 83/100
# 329/329 [==============================] - 94s 280ms/step - loss: 0.5756 - accuracy: 0.8885 - val_loss: 0.7807 - val_accuracy: 0.8482 - lr: 1.0000e-04
# Epoch 84/100
# 329/329 [==============================] - 94s 277ms/step - loss: 0.5788 - accuracy: 0.8879 - val_loss: 0.7884 - val_accuracy: 0.8405 - lr: 1.0000e-04
# Epoch 85/100
# 329/329 [==============================] - 94s 279ms/step - loss: 0.5638 - accuracy: 0.8922 - val_loss: 0.7981 - val_accuracy: 0.8452 - lr: 1.0000e-04
# Epoch 86/100
# 329/329 [==============================] - 94s 278ms/step - loss: 0.5771 - accuracy: 0.8837 - val_loss: 0.8024 - val_accuracy: 0.8428 - lr: 1.0000e-04
# Epoch 87/100
# 329/329 [==============================] - 95s 280ms/step - loss: 0.5565 - accuracy: 0.8925 - val_loss: 0.7624 - val_accuracy: 0.8512 - lr: 1.0000e-04
# Epoch 88/100
# 329/329 [==============================] - 94s 278ms/step - loss: 0.5694 - accuracy: 0.8885 - val_loss: 0.7888 - val_accuracy: 0.8460 - lr: 1.0000e-04
# Epoch 89/100
# 329/329 [==============================] - 94s 277ms/step - loss: 0.5574 - accuracy: 0.8902 - val_loss: 0.7728 - val_accuracy: 0.8463 - lr: 1.0000e-04
# Epoch 90/100
# 329/329 [==============================] - 94s 279ms/step - loss: 0.5493 - accuracy: 0.8904 - val_loss: 0.7813 - val_accuracy: 0.8462 - lr: 1.0000e-04
# Epoch 91/100
# 329/329 [==============================] - 95s 280ms/step - loss: 0.5515 - accuracy: 0.8907 - val_loss: 0.7999 - val_accuracy: 0.8425 - lr: 1.0000e-04
# Epoch 92/100
# 329/329 [==============================] - 94s 278ms/step - loss: 0.5534 - accuracy: 0.8888 - val_loss: 0.7914 - val_accuracy: 0.8437 - lr: 1.0000e-04
# Epoch 93/100
# 329/329 [==============================] - 94s 279ms/step - loss: 0.5589 - accuracy: 0.8865 - val_loss: 0.7955 - val_accuracy: 0.8365 - lr: 1.0000e-04
# Epoch 94/100
# 329/329 [==============================] - 95s 280ms/step - loss: 0.5441 - accuracy: 0.8930 - val_loss: 0.7701 - val_accuracy: 0.8478 - lr: 1.0000e-04
# Epoch 95/100
# 329/329 [==============================] - 95s 280ms/step - loss: 0.5400 - accuracy: 0.8922 - val_loss: 0.7471 - val_accuracy: 0.8547 - lr: 1.0000e-04
# Epoch 96/100
# 329/329 [==============================] - 94s 279ms/step - loss: 0.5301 - accuracy: 0.8946 - val_loss: 0.7660 - val_accuracy: 0.8475 - lr: 1.0000e-04
# Epoch 97/100
# 329/329 [==============================] - 94s 278ms/step - loss: 0.5298 - accuracy: 0.8930 - val_loss: 0.7619 - val_accuracy: 0.8478 - lr: 1.0000e-04
# Epoch 98/100
# 329/329 [==============================] - 94s 279ms/step - loss: 0.5367 - accuracy: 0.8919 - val_loss: 0.7610 - val_accuracy: 0.8512 - lr: 1.0000e-04
# Epoch 99/100
# 329/329 [==============================] - 95s 281ms/step - loss: 0.5383 - accuracy: 0.8910 - val_loss: 0.7916 - val_accuracy: 0.8462 - lr: 1.0000e-04
# Epoch 100/100
# 329/329 [==============================] - 94s 279ms/step - loss: 0.5349 - accuracy: 0.8900 - val_loss: 0.7706 - val_accuracy: 0.8467 - lr: 1.0000e-04

# %%
import matplotlib.pyplot as plt
def plot_training_history(history):
    plt.figure(figsize=(12, 12))
    
    # Pérdida
    plt.figure()
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss during Training')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

    # accuracy
    plt.figure()
    plt.plot(history.history['accuracy'], label='Training accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation accuracy')
    plt.title('accuracy during Training')
    plt.xlabel('Epochs')
    plt.ylabel('accuracy')
    plt.legend()
    plt.show()


# Llamar a la función para graficar el progreso del entrenamiento
plot_training_history(history)

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay
import numpy as np

# Obtener predicciones y etiquetas verdaderas
y_true = []
y_pred = []

for images, labels in final_val_dataset:
    predictions = model.predict(images)
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))
    
accuracy = accuracy_score(y_true, y_pred)
print(f"Accuracy de validación: {accuracy:.2f}")
# Crear la matriz de confusión
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(30))  # Ajusta el rango según tus clases
disp.plot(cmap=plt.cm.Blues)
plt.title("Matriz de Confusión")
plt.show()
# Out:
# 2/2 [==============================] - 4s 250ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 52ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 51ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 56ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 17ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 3s 86ms/step
# Accuracy de validación: 0.84

# %%
history.history['accuracy']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 history.history['accuracy']
#
# NameError: name 'history' is not defined
