# %% [markdown]
# #  Imports

# %%
import tensorflow as tf
from tensorflow.keras import layers, models
import cv2
from tensorflow.keras import Model , layers, Sequential
import os
import numpy as np
import matplotlib.pyplot as plt
import shutil
import random
from sklearn.model_selection import train_test_split

# %%
tf.config.list_physical_devices('GPU')

tf.keras.backend.clear_session()
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Dataset

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
    directory="e:/TFM/PlantsClassification/train",
    labels=None,
    batch_size=None,  # No usar batch aquí para tener control total luego
    image_size=(128, 128),
    color_mode="rgb",
    shuffle=True,
)

val_dataset = tf.keras.utils.image_dataset_from_directory(
    directory="e:/TFM/PlantsClassification/val",
    labels=None,
    batch_size=None,
    image_size=(128, 128),
    color_mode="rgb",
    shuffle=True,
)

test_dataset = tf.keras.utils.image_dataset_from_directory(
    directory="e:/TFM/PlantsClassification/test",
    labels=None,
    batch_size=None,
    image_size=(128, 128),
    color_mode="rgb",
    shuffle=True,
)

# Normalización de imágenes
def normalize(image):
    return tf.cast(image, tf.float32) / 255.0

train_dataset = train_dataset.map(normalize)
val_dataset = val_dataset.map(normalize)
test_dataset = test_dataset.map(normalize)

# Función que convierte a escala de grises como input y conserva el RGB como output
def rgb_to_grayscale_input(image):
    gray = tf.image.rgb_to_grayscale(image)
    gray = tf.image.grayscale_to_rgb(gray)  # Mantiene shape [H, W, 3]
    return gray, image  # (input, target)

# Aplicar la conversión a cada dataset
colorization_train_dataset = train_dataset.map(rgb_to_grayscale_input).shuffle(1000).batch(64).prefetch(tf.data.AUTOTUNE)
colorization_val_dataset = val_dataset.map(rgb_to_grayscale_input).batch(64).prefetch(tf.data.AUTOTUNE)
colorization_test_dataset = test_dataset.map(rgb_to_grayscale_input).batch(64).prefetch(tf.data.AUTOTUNE)
# Out:
# Found 21000 files belonging to 1 classes.
# Found 3000 files belonging to 1 classes.
# Found 6000 files belonging to 1 classes.

# %%
def create_autoencoder(input_shape=(224, 224, 1)):
    model = tf.keras.Sequential([
        # Encoder
        layers.Input(shape=input_shape),
    
        layers.Conv2D(32, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2), padding='same'),
        layers.Dropout(0.2),

        layers.Conv2D(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2), padding='same'),
        layers.Dropout(0.2),

        layers.Conv2D(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2), padding='same'),
        layers.Dropout(0.3),

        layers.Conv2D(256, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.MaxPooling2D((2, 2), padding='same'),
        layers.Dropout(0.3),

        # Bottleneck
        layers.Conv2D(512, (3, 3), activation='relu', padding='same'),
        layers.Conv2D(512, (3, 3), activation='relu', padding='same'),


        # Decoder
        layers.Conv2DTranspose(256, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.UpSampling2D((2, 2)),

        layers.Conv2DTranspose(128, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.UpSampling2D((2, 2)),

        layers.Conv2DTranspose(64, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.UpSampling2D((2, 2)),

        layers.Conv2DTranspose(32, (3, 3), activation='relu', padding='same'),
        layers.BatchNormalization(),
        layers.UpSampling2D((2, 2)),

        # Output
        layers.Conv2D(3, (3, 3), activation='sigmoid', padding='same')
        ])
    return model


model = create_autoencoder((128, 128, 3))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 128, 128, 32)      896
#
#  batch_normalization_8 (Batc  (None, 128, 128, 32)     128
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 64, 64, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_9 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 32, 32, 64)        0
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 128)       73856
#
#  batch_normalization_10 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout_6 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 256)       295168
#
#  batch_normalization_11 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  conv2d_transpose_4 (Conv2DT  (None, 8, 8, 256)        1179904
#  ranspose)
#
#  batch_normalization_12 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  up_sampling2d_4 (UpSampling  (None, 16, 16, 256)      0
#  2D)
#
#  conv2d_transpose_5 (Conv2DT  (None, 16, 16, 128)      295040
#  ranspose)
#
#  batch_normalization_13 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  up_sampling2d_5 (UpSampling  (None, 32, 32, 128)      0
#  2D)
#
#  conv2d_transpose_6 (Conv2DT  (None, 32, 32, 64)       73792
#  ranspose)
#
#  batch_normalization_14 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  up_sampling2d_6 (UpSampling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_transpose_7 (Conv2DT  (None, 64, 64, 32)       18464
#  ranspose)
#
#  batch_normalization_15 (Bat  (None, 64, 64, 32)       128
#  chNormalization)
#
#  up_sampling2d_7 (UpSampling  (None, 128, 128, 32)     0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 3)       867
#
# =================================================================
# Total params: 5,500,291
# Trainable params: 5,498,371
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
def psnr(y_true, y_pred):
    return tf.image.psnr(y_true, y_pred, max_val=1.0)
def ssim(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1.0)

# %%
def psnr(y_true, y_pred):
    return tf.image.psnr(y_true, y_pred, max_val=1.0)
def ssim(y_true, y_pred):
    return tf.image.ssim(y_true, y_pred, max_val=1.0)
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3), loss="mse",metrics=["mae", psnr, ssim])

callbacks = [
    tf.keras.callbacks.ModelCheckpoint("best_autoecoder_colorization.h5", save_best_only=True, monitor="val_loss"),
    tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
    tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=5, min_lr=1e-6, verbose=1),
]
history = model.fit(
    colorization_train_dataset,  # tf.data.Dataset o generator
    verbose=1,  # Mostrar progreso
    validation_data=colorization_test_dataset,  # validación con rotaciones también
    epochs=50,
    batch_size=8,  # Puedes probar 64 o 128 según tu GPU
    callbacks=callbacks,
)
save_path = "best_autoecoder_colorization.h5"
# Out:
# Epoch 1/50
# 329/329 [==============================] - 45s 117ms/step - loss: 0.0321 - mae: 0.1312 - psnr: 15.5481 - ssim: 0.3578 - val_loss: 0.0482 - val_mae: 0.1777 - val_psnr: 13.3736 - val_ssim: 0.3277 - lr: 0.0010
# Epoch 2/50
# 329/329 [==============================] - 38s 112ms/step - loss: 0.0262 - mae: 0.1161 - psnr: 16.3871 - ssim: 0.4033 - val_loss: 0.0271 - val_mae: 0.1261 - val_psnr: 16.0641 - val_ssim: 0.4085 - lr: 0.0010
# Epoch 3/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0239 - mae: 0.1099 - psnr: 16.8081 - ssim: 0.4282 - val_loss: 0.0279 - val_mae: 0.1341 - val_psnr: 15.8461 - val_ssim: 0.4235 - lr: 0.0010
# Epoch 4/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0228 - mae: 0.1068 - psnr: 17.0414 - ssim: 0.4465 - val_loss: 0.0348 - val_mae: 0.1506 - val_psnr: 14.8516 - val_ssim: 0.4204 - lr: 0.0010
# Epoch 5/50
# 329/329 [==============================] - 37s 111ms/step - loss: 0.0230 - mae: 0.1074 - psnr: 17.0041 - ssim: 0.4481 - val_loss: 0.0218 - val_mae: 0.1103 - val_psnr: 17.1287 - val_ssim: 0.4633 - lr: 0.0010
# Epoch 6/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0219 - mae: 0.1043 - psnr: 17.2418 - ssim: 0.4632 - val_loss: 0.0212 - val_mae: 0.1086 - val_psnr: 17.3101 - val_ssim: 0.4715 - lr: 0.0010
# Epoch 7/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0214 - mae: 0.1029 - psnr: 17.3416 - ssim: 0.4699 - val_loss: 0.0230 - val_mae: 0.1109 - val_psnr: 16.9354 - val_ssim: 0.4727 - lr: 0.0010
# Epoch 8/50
# 329/329 [==============================] - 37s 111ms/step - loss: 0.0211 - mae: 0.1021 - psnr: 17.4104 - ssim: 0.4753 - val_loss: 0.0201 - val_mae: 0.0987 - val_psnr: 17.6465 - val_ssim: 0.4903 - lr: 0.0010
# Epoch 9/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0204 - mae: 0.0998 - psnr: 17.5818 - ssim: 0.4843 - val_loss: 0.0237 - val_mae: 0.1224 - val_psnr: 16.5913 - val_ssim: 0.4847 - lr: 0.0010
# Epoch 10/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.
50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0146 - mae: 0.0823 - psnr: 19.0473 - ssim: 0.5320 - val_loss: 0.0162 - val_mae: 0.0899 - val_psnr: 18.6646 - val_ssim: 0.5327 - lr: 0.0010
# Epoch 25/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0142 - mae: 0.0809 - psnr: 19.1913 - ssim: 0.5359 - val_loss: 0.0176 - val_mae: 0.0955 - val_psnr: 18.1530 - val_ssim: 0.5297 - lr: 0.0010
# Epoch 26/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0140 - mae: 0.0804 - psnr: 19.2357 - ssim: 0.5369 - val_loss: 0.0166 - val_mae: 0.0870 - val_psnr: 18.6554 - val_ssim: 0.5423 - lr: 0.0010
# Epoch 27/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0137 - mae: 0.0791 - psnr: 19.3575 - ssim: 0.5400 - val_loss: 0.0193 - val_mae: 0.0978 - val_psnr: 17.8596 - val_ssim: 0.5288 - lr: 0.0010
# Epoch 28/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0146 - mae: 0.0824 - psnr: 19.0403 - ssim: 0.5300 - val_loss: 0.0176 - val_mae: 0.0986 - val_psnr: 18.1203 - val_ssim: 0.5432 - lr: 0.0010
# Epoch 29/50
# 328/329 [============================>.] - ETA: 0s - loss: 0.0136 - mae: 0.0791 - psnr: 19.3656 - ssim: 0.5404
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0136 - mae: 0.0791 - psnr: 19.3653 - ssim: 0.5404 - val_loss: 0.0164 - val_mae: 0.0906 - val_psnr: 18.6278 - val_ssim: 0.5429 - lr: 0.0010
# Epoch 30/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0130 - mae: 0.0766 - psnr: 19.6172 - ssim: 0.5451 - val_loss: 0.0161 - val_mae: 0.0929 - val_psnr: 18.6269 - val_ssim: 0.5439 - lr: 5.0000e-04
# Epoch 31/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0128 - mae: 0.0760 - psnr: 19.6724 - ssim: 0.5465 - val_loss: 0.0155 - val_mae: 0.0857 - val_psnr: 18.9405 - val_ssim: 0.5485 - lr: 5.0000e-04
# Epoch 32/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0127 - mae: 0.0755 - psnr: 19.7138 - ssim: 0.5479 - val_loss: 0.0167 - val_mae: 0.0933 - val_psnr: 18.4703 - val_ssim: 0.5435 - lr: 5.0000e-04
# Epoch 33/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0127 - mae: 0.0755 - psnr: 19.7189 - ssim: 0.5487 - val_loss: 0.0161 - val_mae: 0.0921 - val_psnr: 18.6619 - val_ssim: 0.5480 - lr: 5.0000e-04
# Epoch 34/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0125 - mae: 0.0747 - psnr: 19.8004 - ssim: 0.5504 - val_loss: 0.0160 - val_mae: 0.0926 - val_psnr: 18.6631 - val_ssim: 0.5491 - lr: 5.0000e-04
# Epoch 35/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0124 - mae: 0.0745 - psnr: 19.8194 - ssim: 0.5513 - val_loss: 0.0155 - val_mae: 0.0890 - val_psnr: 18.8524 - val_ssim: 0.5488 - lr: 5.0000e-04
# Epoch 36/50
# 328/329 [============================>.] - ETA: 0s - loss: 0.0124 - mae: 0.0744 - psnr: 19.8292 - ssim: 0.5519
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 329/329 [==============================] - 37s 110ms/step - loss: 0.
50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0115 - mae: 0.0711 - psnr: 20.1808 - ssim: 0.5605 - val_loss: 0.0150 - val_mae: 0.0876 - val_psnr: 19.0511 - val_ssim: 0.5585 - lr: 1.2500e-04
# Epoch 50/50
# 329/329 [==============================] - 37s 110ms/step - loss: 0.0115 - mae: 0.0711 - psnr: 20.1866 - ssim: 0.5608 - val_loss: 0.0149 - val_mae: 0.0868 - val_psnr: 19.1126 - val_ssim: 0.5591 - lr: 1.2500e-04

# %%
def plot_training_history(history):
    plt.figure(figsize=(12, 6))
    
    # Pérdida
    plt.figure()
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.title('Loss during Training')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

    # PSNR
    plt.figure()
    plt.plot(history.history['psnr'], label='Training PSNR')
    plt.plot(history.history['val_psnr'], label='Validation PSNR')
    plt.title('PSNR during Training')
    plt.xlabel('Epochs')
    plt.ylabel('PSNR')
    plt.legend()
    plt.show()

    # SSIM
    plt.figure()
    plt.plot(history.history['ssim'], label='Training SSIM')
    plt.plot(history.history['val_ssim'], label='Validation SSIM')
    plt.title('SSIM during Training')
    plt.xlabel('Epochs')
    plt.ylabel('SSIM')
    plt.legend()
    plt.show()

# Llamar a la función para graficar el progreso del entrenamiento
plot_training_history(history)

# %%
def show_colorization_examples(dataset, model, n=5):
    for images_gray, images_real in dataset.take(1):
        preds = model.predict(images_gray)

        for i in range(n):
            plt.figure(figsize=(10, 3))

            plt.subplot(1, 3, 1)
            plt.imshow(images_gray[i])
            plt.title("Input (grayscale)")
            plt.axis("off")

            plt.subplot(1, 3, 2)
            plt.imshow(preds[i])
            plt.title("Predicción (color)")
            plt.axis("off")

            plt.subplot(1, 3, 3)
            plt.imshow(images_real[i])
            plt.title("Original")
            plt.axis("off")

            plt.show()
show_colorization_examples(colorization_val_dataset, model, n=5)
# Out:
# 2/2 [==============================] - 1s 7ms/step

# %%
classification_train_dataset = tf.keras.utils.image_dataset_from_directory(
    directory="e:/TFM/PlantsClassification/train",
    image_size=(128, 128),
    batch_size=64,
    label_mode="int",        # o "categorical" según el loss
    color_mode="rgb",       
    shuffle=True
).map(lambda x, y: (tf.cast(x, tf.float32) / 255.0, y)).shuffle(1000).prefetch(tf.data.AUTOTUNE)
classification_val_dataset = tf.keras.utils.image_dataset_from_directory(
    directory="e:/TFM/PlantsClassification/val",
    image_size=(128, 128),
    batch_size=64,
    label_mode="int",
    color_mode="rgb",
    shuffle=False
).map(lambda x, y: (tf.cast(x, tf.float32) / 255.0, y)).shuffle(1000).prefetch(tf.data.AUTOTUNE)

classification_test_dataset = tf.keras.utils.image_dataset_from_directory(
    directory="e:/TFM/PlantsClassification/test",
    image_size=(128, 128),
    batch_size=64,
    label_mode="int",
    color_mode="rgb",
    shuffle=False
).map(lambda x, y: (tf.cast(x, tf.float32) / 255.0, y)).shuffle(1000).prefetch(tf.data.AUTOTUNE)
# Out:
# Found 21000 files belonging to 30 classes.
# Found 3000 files belonging to 30 classes.
# Found 6000 files belonging to 30 classes.

# %%
model = tf.keras.models.load_model("best_autoecoder_colorization.h5", custom_objects={'psnr': psnr, 'ssim': ssim})
autoencoder=model
autoencoder.trainable = False
autoencoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 128, 128, 32)      896
#
#  batch_normalization_8 (Batc  (None, 128, 128, 32)     128
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 64, 64, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_9 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 32, 32, 64)        0
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 128)       73856
#
#  batch_normalization_10 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout_6 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 256)       295168
#
#  batch_normalization_11 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 512)         2359808
#
#  conv2d_transpose_4 (Conv2DT  (None, 8, 8, 256)        1179904
#  ranspose)
#
#  batch_normalization_12 (Bat  (None, 8, 8, 256)        1024
#  chNormalization)
#
#  up_sampling2d_4 (UpSampling  (None, 16, 16, 256)      0
#  2D)
#
#  conv2d_transpose_5 (Conv2DT  (None, 16, 16, 128)      295040
#  ranspose)
#
#  batch_normalization_13 (Bat  (None, 16, 16, 128)      512
#  chNormalization)
#
#  up_sampling2d_5 (UpSampling  (None, 32, 32, 128)      0
#  2D)
#
#  conv2d_transpose_6 (Conv2DT  (None, 32, 32, 64)       73792
#  ranspose)
#
#  batch_normalization_14 (Bat  (None, 32, 32, 64)       256
#  chNormalization)
#
#  up_sampling2d_6 (UpSampling  (None, 64, 64, 64)       0
#  2D)
#
#  conv2d_transpose_7 (Conv2DT  (None, 64, 64, 32)       18464
#  ranspose)
#
#  batch_normalization_15 (Bat  (None, 64, 64, 32)       128
#  chNormalization)
#
#  up_sampling2d_7 (UpSampling  (None, 128, 128, 32)     0
#  2D)
#
#  conv2d_13 (Conv2D)          (None, 128, 128, 3)       867
#
# =================================================================
# Total params: 5,500,291
# Trainable params: 0
# Non-trainable params: 5,500,291
# _________________________________________________________________

# %%
def get_encoder(autoencoder):
    # Extraemos las capas del encoder (hasta MaxPooling2D final)

    encoder = tf.keras.Sequential(autoencoder.layers[:18])

    return encoder
encoder = get_encoder(model)
# Build the encoder model with the appropriate input shape
encoder.build(input_shape=(None, 128, 128, 3))  # Replace with the correct input shape if different

# Descongelar las dos últimas capas del encoder
encoder.layers[-1].trainable = True
encoder.layers[-2].trainable = True
encoder.layers[-3].trainable = True
encoder.layers[-4].trainable = True
encoder.layers[-5].trainable = True
encoder.layers[-6].trainable = True
encoder.summary()
# Out:
# Model: "sequential_20"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_7 (Conv2D)           (None, 128, 128, 32)      896
#
#  batch_normalization_8 (Batc  (None, 128, 128, 32)     128
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 64, 64, 32)       0
#  2D)
#
#  dropout_4 (Dropout)         (None, 64, 64, 32)        0
#
#  conv2d_8 (Conv2D)           (None, 64, 64, 64)        18496
#
#  batch_normalization_9 (Batc  (None, 64, 64, 64)       256
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 32, 32, 64)       0
#  2D)
#
#  dropout_5 (Dropout)         (None, 32, 32, 64)        0
#
#  conv2d_9 (Conv2D)           (None, 32, 32, 128)       73856
#
#  batch_normalization_10 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 16, 16, 128)      0
#  2D)
#
#  dropout_6 (Dropout)         (None, 16, 16, 128)       0
#
#  conv2d_10 (Conv2D)          (None, 16, 16, 256)       295168
#
#  batch_normalization_11 (Bat  (None, 16, 16, 256)      1024
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_11 (Conv2D)          (None, 8, 8, 512)         1180160
#
#  conv2d_12 (Conv2D)          (None, 8, 8, 512)         2359808
#
# =================================================================
# Total params: 3,930,304
# Trainable params: 3,835,648
# Non-trainable params: 94,656
# _________________________________________________________________

# %%
def create_classifier(encoder, num_classes=30, train_encoder=False):


    model = tf.keras.Sequential([
        encoder,
        layers.GlobalAveragePooling2D(),
        layers.BatchNormalization(),
        layers.Dense(512, activation='relu'),
        layers.Dropout(0.2),
        layers.BatchNormalization(),
        layers.Dense(256, activation='relu'),
        layers.Dropout(0.2),
        layers.Dense(num_classes, activation='softmax')
    ])
    return model

# %%
classifier = create_classifier(encoder, num_classes=30, train_encoder=False)
classifier.build(input_shape=(None, 128, 128, 3))  # Replace with the correct input shape if different
classifier.summary()
# Out:
# Model: "sequential_21"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_20 (Sequential)  (None, 8, 8, 512)         3930304
#
#  global_average_pooling2d_5   (None, 512)              0
#  (GlobalAveragePooling2D)
#
#  batch_normalization_26 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_15 (Dense)            (None, 512)               262656
#
#  dropout_18 (Dropout)        (None, 512)               0
#
#  batch_normalization_27 (Bat  (None, 512)              2048
#  chNormalization)
#
#  dense_16 (Dense)            (None, 256)               131328
#
#  dropout_19 (Dropout)        (None, 256)               0
#
#  dense_17 (Dense)            (None, 30)                7710
#
# =================================================================
# Total params: 4,336,094
# Trainable params: 4,239,390
# Non-trainable params: 96,704
# _________________________________________________________________

# %%
#load the best autoencoder

classifier.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3, decay=1e-5),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

history=classifier.fit(
    classification_train_dataset,  # dataset con labels
    validation_data=classification_val_dataset,
    epochs=50,
    batch_size=64,
    callbacks=[
        tf.keras.callbacks.EarlyStopping(patience=10, restore_best_weights=True),
        tf.keras.callbacks.ReduceLROnPlateau(monitor="val_loss", patience=5,factor=0.5, min_lr=1e-6, verbose=1),
        tf.keras.callbacks.ModelCheckpoint("best_classifier.h5", save_best_only=True)
    ]
)
# save
classifier.save("best_classifier_Autoencoder.h5")
# Out:
# Epoch 1/50
# 329/329 [==============================] - 23s 34ms/step - loss: 2.5563 - accuracy: 0.2933 - val_loss: 1.9693 - val_accuracy: 0.4520 - lr: 0.0010
# Epoch 2/50
# 329/329 [==============================] - 21s 32ms/step - loss: 1.7075 - accuracy: 0.4949 - val_loss: 1.8363 - val_accuracy: 0.4920 - lr: 0.0010
# Epoch 3/50
# 329/329 [==============================] - 20s 32ms/step - loss: 1.2349 - accuracy: 0.6225 - val_loss: 1.5583 - val_accuracy: 0.5830 - lr: 0.0010
# Epoch 4/50
# 329/329 [==============================] - 20s 32ms/step - loss: 0.8908 - accuracy: 0.7197 - val_loss: 1.4516 - val_accuracy: 0.6220 - lr: 0.0010
# Epoch 5/50
# 329/329 [==============================] - 20s 32ms/step - loss: 0.6523 - accuracy: 0.7896 - val_loss: 1.7998 - val_accuracy: 0.5830 - lr: 0.0010
# Epoch 6/50
# 329/329 [==============================] - 20s 32ms/step - loss: 0.5250 - accuracy: 0.8216 - val_loss: 1.5321 - val_accuracy: 0.6630 - lr: 0.0010
# Epoch 7/50
# 329/329 [==============================] - 20s 32ms/step - loss: 0.3617 - accuracy: 0.8672 - val_loss: 1.7497 - val_accuracy: 0.6597 - lr: 0.0010
# Epoch 8/50
# 329/329 [==============================] - 20s 32ms/step - loss: 0.3382 - accuracy: 0.8765 - val_loss: 1.7024 - val_accuracy: 0.6743 - lr: 0.0010
# Epoch 9/50
# 328/329 [============================>.] - ETA: 0s - loss: 0.3124 - accuracy: 0.8850
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 329/329 [==============================] - 20s 32ms/step - loss: 0.3121 - accuracy: 0.8850 - val_loss: 1.7802 - val_accuracy: 0.6560 - lr: 0.0010
# Epoch 10/50
# 329/329 [==============================] - 20s 32ms/step - loss: 0.2071 - accuracy: 0.9182 - val_loss: 1.6278 - val_accuracy: 0.6887 - lr: 5.0000e-04
# Epoch 11/50
# 329/329 [==============================] - 20s 32ms/step - loss: 0.1446 - accuracy: 0.9354 - val_loss: 1.6895 - val_accuracy: 0.6893 - lr: 5.0000e-04
# Epoch 12/50
# 329/329 [==============================] - 20s 32ms/step - loss: 0.1197 - accuracy: 0.9435 - val_loss: 1.7413 - val_accuracy: 0.6923 - lr: 5.0000e-04
# Epoch 13/50
# 329/329 [==============================] - 20s 32ms/step - loss: 0.1100 - accuracy: 0.9474 - val_loss: 1.7367 - val_accuracy: 0.6920 - lr: 5.0000e-04
# Epoch 14/50
# 328/329 [============================>.] - ETA: 0s - loss: 0.1035 - accuracy: 0.9486
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 329/329 [==============================] - 20s 32ms/step - loss: 0.1039 - accuracy: 0.9485 - val_loss: 1.7928 - val_accuracy: 0.6917 - lr: 5.0000e-04

# %%
plt.figure(figsize=(12, 6))

# Gráfico de pérdida
plt.subplot(1, 2, 1)
plt.plot(history.history["loss"], label="Training Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.title("Training and Validation Loss")
plt.legend()
plt.grid()

# Gráfico de precisión
plt.subplot(1, 2, 2)
plt.plot(history.history["accuracy"], label="Training Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.title("Training and Validation Accuracy")
plt.legend()
plt.grid()

plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay,accuracy_score
import numpy as np

y_true = []
y_pred = []

for images, labels in classification_val_dataset:
    predictions = classifier.predict(images)  # Use the classifier model
    y_true.extend(labels.numpy())
    y_pred.extend(np.argmax(predictions, axis=1))

# Convertir y_true y y_pred a arrays numpy
y_true = np.array(y_true)
y_pred = np.array(y_pred)

# Calcular precisión
accuracy = accuracy_score(y_true, y_pred)
print(f"Accuracy: {accuracy:.2%}")

# Crear la matriz de confusión
num_classes = len(np.unique(y_true))  # Determinar dinámicamente el número de clases
cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=range(num_classes))
disp.plot(cmap=plt.cm.Blues)
plt.title("Matriz de Confusión")

plt.show()
# Out:
# 2/2 [==============================] - 0s 254ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 998us/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 9ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 10ms/step
# 2/2 [==============================] - 0s 3ms/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 6ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 7ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 14ms/step
# 2/2 [==============================] - 0s 8ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 5ms/step
# 2/2 [==============================] - 0s 0s/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 16ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 16ms/step
# Accuracy: 62.20%
